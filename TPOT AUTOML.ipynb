# %% [markdown]
# # TPOT AUTOML

# %%
from tpot import TPOTRegressor
import pandas as pd
from pandas import read_excel
from sklearn.model_selection import train_test_split

# %%
filename='C:\Z\Z Workspace\Practice\Projects\AirQuality Index Krish\Data\Real-Data\Real_Combine.csv'
df=pd.read_csv(filename,header=0)
df.head(5)
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM      PM 2.5
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4  219.720833
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1  182.187500
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1  154.037500
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6  223.208333
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2  200.645833

# %%
'''
import tkinter as tk
from tkinter import filedialog
import pandas as pd

root= tk.Tk()

canvas1 = tk.Canvas(root, width = 300, height = 300, bg = 'lightsteelblue')
canvas1.pack()

def getExcel ():
    global df
    
    import_file_path = filedialog.askopenfilename()
    df = pd.read_excel (import_file_path)
    print (df)
    
browseButton_Excel = tk.Button(text='Import Excel File', command=getExcel, bg='green', fg='white', font=('helvetica', 12, 'bold'))
canvas1.create_window(150, 150, window=browseButton_Excel)

root.mainloop()
'''
# Out:
# "\nimport tkinter as tk\nfrom tkinter import filedialog\nimport pandas as pd\n\nroot= tk.Tk()\n\ncanvas1 = tk.Canvas(root, width = 300, height = 300, bg = 'lightsteelblue')\ncanvas1.pack()\n\ndef getExcel ():\n    global df\n    \n    import_file_path = filedialog.askopenfilename()\n    df = pd.read_excel (import_file_path)\n    print (df)\n    \nbrowseButton_Excel = tk.Button(text='Import Excel File', command=getExcel, bg='green', fg='white', font=('helvetica', 12, 'bold'))\ncanvas1.create_window(150, 150, window=browseButton_Excel)\n\nroot.mainloop()\n"

# %%
df.head(5)
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM      PM 2.5
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4  219.720833
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1  182.187500
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1  154.037500
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6  223.208333
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2  200.645833

# %%
dftarget=df['PM 2.5']

# %%
df=df.dropna()
X=df.iloc[:,:-1] ## independent features
y=df.iloc[:,-1] ## dependent features

# %%
## check null values
X.isnull()
# Out:
#           T     TM     Tm    SLP      H     VV      V     VM
# 0     False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False
# 5     False  False  False  False  False  False  False  False
# 6     False  False  False  False  False  False  False  False
# 7     False  False  False  False  False  False  False  False
# 8     False  False  False  False  False  False  False  False
# 9     False  False  False  False  False  False  False  False
# 10    False  False  False  False  False  False  False  False
# 11    False  False  False  False  False  False  False  False
# 12    False  False  False  False  False  False  False  False
# 13    False  False  False  False  False  False  False  False
# ...

# %%
type(df)
df
# Out:
#          T    TM    Tm     SLP     H   VV     V    VM      PM 2.5
# 0      7.4   9.8   4.8  1017.6  93.0  0.5   4.3   9.4  219.720833
# 1      7.8  12.7   4.4  1018.5  87.0  0.6   4.4  11.1  182.187500
# 2      6.7  13.4   2.4  1019.4  82.0  0.6   4.8  11.1  154.037500
# 3      8.6  15.5   3.3  1018.7  72.0  0.8   8.1  20.6  223.208333
# 4     12.4  20.9   4.4  1017.3  61.0  1.3   8.7  22.2  200.645833
# 5     16.0  25.2  10.0  1013.2  79.0  0.6   4.8  11.1  285.225000
# 6     13.4  21.0   9.2  1015.1  87.0  0.5   1.5   7.6  236.825000
# 7     14.3  22.6   6.6  1016.3  76.0  0.8   0.4   3.5  276.908333
# 8     12.7  18.9   7.3  1021.2  76.0  1.8   6.1  16.5  108.000000
# 9     11.9  18.9   6.3  1020.1  76.0  1.1   8.3  20.6  107.625000
# 10    12.2  19.9   6.2  1021.0  69.0  2.1   4.4  18.3  125.891667
# 11    13.4  21.1   5.6  1020.0  60.0  1.9   8.0  22.2  181.012500
# 12    12.3  21.4   6.4  1019.6  70.0  1.9   6.7  14.8  152.554167
# ...

# %%
y.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1059    False
# 1060    False
# 1061    False
# 1062    False
# 1063    False
# 1064    False
# 1065    False
# 1066    False
# 1067    False
# 1068    False
# 1069    False
# 1070    False
# 1071    False
# 1072    False
# 1073    False
# 1074    False
# 1075    False
# 1076    False
# 1077    False
# 1078    False
# 1079    False
# 1080    False
# 1081    False
# 1082    False
# 1083    False
# 1084    False
# 1085    False
# 1086    False
# 1087    False
# 1088    False
# ...

# %%
df=df.drop(columns=['PM 2.5'])

# %%
df.head(5),dftarget.head(5)
# Out:
# (      T    TM   Tm     SLP     H   VV    V    VM
#  0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4
#  1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1
#  2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1
#  3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6
#  4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2, 0    219.720833
#  1    182.187500
#  2    154.037500
#  3    223.208333
#  4    200.645833
#  Name: PM 2.5, dtype: float64)

# %%
dfnp=df.to_numpy()
dftargetnp=dftarget.to_numpy()

# %%
dfnp[:,:],dftargetnp
# Out:
# (array([[ 7.4,  9.8,  4.8, ...,  0.5,  4.3,  9.4],
#         [ 7.8, 12.7,  4.4, ...,  0.6,  4.4, 11.1],
#         [ 6.7, 13.4,  2.4, ...,  0.6,  4.8, 11.1],
#         ...,
#         [12.3, 19.4,  6.2, ...,  1.3,  6.7, 25.9],
#         [11.1, 20.6,  3.6, ...,  1.3,  3. ,  9.4],
#         [11.6, 21.4,  3.4, ...,  1.1,  2.4,  5.4]]),
#  array([219.72083333, 182.1875    , 154.0375    , ..., 204.375     ,
#         223.25      , 248.95833333]))

# %%
type(dfnp),type(dftargetnp)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
type(df),type(dftarget)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
X_train, X_test, y_train, y_test = train_test_split(dfnp, dftargetnp,
                                                    train_size=0.75, test_size=0.25)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((816, 8), (272, 8), (816,), (272,))

# %%
from sklearn.preprocessing import MinMaxScaler
sc_X = MinMaxScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
X_test
# Out:
# array([[0.90064103, 0.92436975, 0.70570571, ..., 0.54054054, 0.38333333,
#         0.29443447],
#        [0.20833333, 0.30812325, 0.17117117, ..., 0.2972973 , 0.3375    ,
#         0.23159785],
#        [0.33653846, 0.41456583, 0.24924925, ..., 0.2972973 , 0.35416667,
#         0.23159785],
#        ...,
#        [0.81410256, 0.81792717, 0.6996997 , ..., 0.75675676, 0.22916667,
#         0.33572711],
#        [0.80769231, 0.8627451 , 0.78078078, ..., 0.43243243, 0.54583333,
#         0.33572711],
#        [0.32692308, 0.43977591, 0.29429429, ..., 0.54054054, 0.21666667,
#         0.36445242]])

# %%
X_train
# Out:
# array([[0.77564103, 0.70588235, 0.80780781, ..., 0.43243243, 0.22916667,
#         0.23159785],
#        [0.39102564, 0.51260504, 0.23723724, ..., 0.43243243, 0.12916667,
#         0.13464991],
#        [0.38141026, 0.49019608, 0.35435435, ..., 0.62162162, 0.14583333,
#         0.19928187],
#        ...,
#        [0.77564103, 0.71988796, 0.81081081, ..., 0.43243243, 0.59166667,
#         0.46499102],
#        [0.58333333, 0.61344538, 0.45345345, ..., 0.62162162, 0.22916667,
#         0.19928187],
#        [0.64102564, 0.52941176, 0.73573574, ..., 0.43243243, 0.1125    ,
#         0.19928187]])

# %%
tpot = TPOTRegressor(verbosity=2, max_time_mins=10)
tpot.fit(X_train, y_train)
print(tpot.score(X_test, y_test))
# Out:
# ...
# Generation 1 - Current best internal CV score: -2640.9027375858
# Generation 2 - Current best internal CV score: -2640.9027375858
# Generation 3 - Current best internal CV score: -2620.5544752808864
# Generation 4 - Current best internal CV score: -2581.334620346249
# Generation 5 - Current best internal CV score: -2577.5640312622163
#
# 10.968137983333333 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: ExtraTreesRegressor(PCA(input_matrix, iterated_power=7, svd_solver=randomized), bootstrap=False, max_features=1.0, min_samples_leaf=1, min_samples_split=9, n_estimators=100)
# -2691.2502967273895

# %%
tpot.fitted_pipeline_
# Out:
# Pipeline(memory=None,
#      steps=[('pca', PCA(copy=True, iterated_power=7, n_components=None, random_state=None,
#   svd_solver='randomized', tol=0.0, whiten=False)), ('extratreesregressor', ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=None,
#           max_features=1.0, max_leaf_nodes=None, min_impurity_decrea...ators=100, n_jobs=None,
#           oob_score=False, random_state=None, verbose=0, warm_start=False))])

# %%
print(tpot.score(X_test, y_test))
# Out:
# -2691.2502967273895
